# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\Parthiban\Downloads\bank real.csv')

# %%
data.shape
# Out:
# (1309, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3     Braund    male  22.0      1      0
# 1            2         1       1    Cumings  female  38.0      1      0
# 2            3         1       3  Heikkinen  female  26.0      0      0
# 3            4         1       1   Futrelle  female  35.0      1      0
# 4            5         0       3      Allen    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#       PassengerId  Survived  Pclass           Name     Sex   Age  SibSp  \
# 1304         1305         0       3        Spector    male   NaN      0
# 1305         1306         1       1  Oliva y Ocana  female  39.0      0
# 1306         1307         0       3        Saether    male  38.5      0
# 1307         1308         0       3           Ware    male   NaN      0
# 1308         1309         0       3          Peter    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C

# %%
data.describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000     0.377387     2.294882    29.881138     0.498854
# std     378.020061     0.484918     0.837836    14.413493     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     328.000000     0.000000     2.000000    21.000000     0.000000
# 50%     655.000000     0.000000     3.000000    28.000000     0.000000
# 75%     982.000000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
data.shape
# Out:
# (1309, 12)

# %%
data.nunique()
# Out:
# PassengerId    1309
# Survived          2
# Pclass            3
# Name            875
# Sex               2
# Age              98
# SibSp             7
# Parch             8
# Ticket          929
# Fare            281
# Cabin           186
# Embarked          3
# dtype: int64

# %%
data['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
clean_data = data.drop(['Cabin','Ticket','Parch','Name','Sex','Embarked'],axis=1)

# %%
clean_data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp     Fare
# 0            1         0       3  22.0      1   7.2500
# 1            2         1       1  38.0      1  71.2833
# 2            3         1       3  26.0      0   7.9250
# 3            4         1       1  35.0      1  53.1000
# 4            5         0       3  35.0      0   8.0500

# %%
data.dropna(subset=["Embarked"], inplace=True)
data["Cabin"].fillna("Unknown", inplace=True)
data["Age"].fillna(data["Age"].mean(), inplace=True)

# %%
data.head(50)
# Out:
#     PassengerId  Survived  Pclass            Name     Sex        Age  SibSp  \
# 0             1         0       3          Braund    male  22.000000      1
# 1             2         1       1         Cumings  female  38.000000      1
# 2             3         1       3       Heikkinen  female  26.000000      0
# 3             4         1       1        Futrelle  female  35.000000      1
# 4             5         0       3           Allen    male  35.000000      0
# 5             6         0       3           Moran    male  29.842596      0
# 6             7         0       1        McCarthy    male  54.000000      0
# 7             8         0       3         Palsson    male   2.000000      3
# 8             9         1       3         Johnson  female  27.000000      0
# 9            10         1       2          Nasser  female  14.000000      1
# 10           11         1       3       Sandstrom  female   4.000000      1
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(6, 3))
sns.histplot(data["Age"], kde=True)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6, 3))
sns.countplot(data=data, x="Sex", hue="Survived")
plt.title("Survival by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Survived", loc="upper right")
plt.show()

# %%
plt.figure(figsize=(6, 3))
sns.scatterplot(data=data, x="Age", y="Fare", hue="Survived")
plt.title("Scatter Plot of Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title="Survived")
plt.show()

# %%
corelation=clean_data.corr()

# %%
plt.figure(figsize=(23,10))
sns.heatmap(clean_data.corr(), cmap='bwr', annot=True)
plt.show()

# %%
# Conclusion and Key Insights

In this task, we embarked on a journey to clean the data given and done a exploratory data analysis in a titanic data set to identify a key instites and made predictive analysis. Let's recap the key takeaways and insights from this endeavor:

**Data Pre-processing:**

The initial data inspection revealed unstructured dataset with some missing values. While we encountered some duplicate entries, they were not considered as errors.

**Exploratory Data Analysis (EDA):**

- The age distribution of clients highlighted that the majority fell in the 20-40 age range.
- As comparing the survival rate by gender survival of female relatively higher then the survival of male.
- Passengers who brought higher class ticket with high fare survied the most.
- As analysed most of female survied in all three classes then male.
